# %% [markdown]
# <a href="https://colab.research.google.com/github/DeanWookey/documentation/blob/master/faster_whisper_youtube_drive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Youtube/Google Drive Videos Translation/Transcription with Faster Whisper**
#
# [faster-whisper](https://github.com/guillaumekln/faster-whisper) is a reimplementation of OpenAI's Whisper model using CTranslate2, which is a fast inference engine for Transformer models.
#
# This implementation is up to 4 times faster than openai/whisper for the same accuracy while using less memory. The efficiency can be further improved with 8-bit quantization on both CPU and GPU.
#
# Whisper is a general-purpose speech recognition model. It is trained on a large dataset of diverse audio and is also a multi-task model that can perform multilingual speech recognition as well as speech translation and language identification.
#
# This Notebook will guide you through the transcription or translation of a  video file (from Youtube/Google Drive) using Faster Whisper. You'll be able to explore most inference parameters or use the Notebook as-is to store the output and video audio in your Google Drive.
#
# ## **How to use**
# 1. Read and understand the notebook. You should at the very least modify the **video selection section** to choose the video you wish to translate/transcribe
# 2. Click Runtime -> Run all and wait for the notebook to do its magic, alternatively you may run the cells one by one and skip the Google Drive portion if you do not intend to use it
# 3. A download prompt should appear once subtitles is ready, or check the 'Files' tab on the left for the output

# %%
#@markdown # **[Optional]** Access data in Google Drive 💾
#@markdown Enter a Google Drive path and run this cell to store the results inside Google Drive.

# Uncomment to copy generated images to drive, faster than downloading directly from colab in my experience.
from google.colab import drive
from pathlib import Path

drive_mount_path = Path("/") / "content" / "drive"
drive.mount(str(drive_mount_path))
drive_mount_path /= "My Drive"
#@markdown ---
drive_path = "Colab Notebooks/Faster Whisper" #@param {type:"string"}
#@markdown ---
#@markdown **Run this cell again if you change your Google Drive path.**

drive_whisper_path = drive_mount_path / Path(drive_path.lstrip("/"))
drive_whisper_path.mkdir(parents=True, exist_ok=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#@markdown # **Check GPU type** 🕵️

#@markdown The type of GPU you get assigned in your Colab session defined the speed at which the video will be transcribed.
#@markdown The higher the number of floating point operations per second (FLOPS), the faster the transcription.
#@markdown But even the least powerful GPU available in Colab is able to run any Whisper model.
#@markdown Make sure you've selected `GPU` as hardware accelerator for the Notebook (Runtime &rarr; Change runtime type &rarr; Hardware accelerator).

#@markdown |  GPU   |  GPU RAM   | FP32 teraFLOPS |     Availability   |
#@markdown |:------:|:----------:|:--------------:|:------------------:|
#@markdown |  T4    |    16 GB   |       8.1      |         Free       |
#@markdown | P100   |    16 GB   |      10.6      |      Colab Pro     |
#@markdown | V100   |    16 GB   |      15.7      |  Colab Pro (Rare)  |

#@markdown ---
#@markdown **Factory reset your Notebook's runtime if you want to get assigned a new GPU.**

# !nvidia-smi -L

# !nvidia-smi
# Out:
# GPU 0: Tesla T4 (UUID: GPU-fb3c81c3-5524-7bbf-aa63-5f93190ac2a3)
# Tue Nov 12 08:26:35 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   65C    P0              29W /  70W |   3329MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# +---------------------------------------------------------------------------------------+

# %%
#@markdown # **Install libraries** 🏗️
#@markdown This cell will take a little while to download several libraries, including Faster Whisper.

#@markdown ---

! pip install faster-whisper
! pip install yt-dlp
! pip install ctranslate2==4.4.0


import os
import sys
import warnings
from faster_whisper import WhisperModel
import yt_dlp
import subprocess
import torch
import shutil
import numpy as np
from IPython.display import display, Markdown, YouTubeVideo
import requests
from urllib.parse import urlsplit
from google.colab import files
from pathlib import Path

device = torch.device('cuda:0')
print('Using device:', device, file=sys.stderr)

# !sudo apt-get update
# !sudo apt install nvidia-cuda-toolkit
# Out:
# Requirement already satisfied: faster-whisper in /usr/local/lib/python3.10/dist-packages (1.0.3)
# Requirement already satisfied: av<13,>=11.0 in /usr/local/lib/python3.10/dist-packages (from faster-whisper) (12.3.0)
# Requirement already satisfied: ctranslate2<5,>=4.0 in /usr/local/lib/python3.10/dist-packages (from faster-whisper) (4.4.0)
# Requirement already satisfied: huggingface-hub>=0.13 in /usr/local/lib/python3.10/dist-packages (from faster-whisper) (0.24.7)
# Requirement already satisfied: tokenizers<1,>=0.13 in /usr/local/lib/python3.10/dist-packages (from faster-whisper) (0.19.1)
# Requirement already satisfied: onnxruntime<2,>=1.14 in /usr/local/lib/python3.10/dist-packages (from faster-whisper) (1.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from ctranslate2<5,>=4.0->faster-whisper) (75.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ctranslate2<5,>=4.0->faster-whisper) (1.26.4)
# Requirement already satisfied: pyyaml<7,>=5.3 in /usr/local/lib/python3.10/dist-packages (from ctranslate2<5,>=4.0->faster-whisper) (6.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13->faster-whisper) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13->faster-whisper) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13->faster-whisper) (24.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13->faster-whisper) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13->faster-whisper) (4.66.6)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13->faster-whisper) (4.12.2)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from onnxruntime<2,>=1.14->faster-whisper) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime<2,>=1.14->faster-whisper) (24.3.25)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime<2,>=1.14->faster-whisper) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime<2,>=1.14->faster-whisper) (1.13.1)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->onnxruntime<2,>=1.14->faster-whisper) (10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime<2,>=1.14->faster-whisper) (1.3.0)
# Requirement already satisfied: yt-dlp in /usr/local/lib/python3.10/dist-packages (2024.11.4)
# Requirement already satisfied: ctranslate2==4.4.0 in /usr/local/lib/python3.10/dist-packages (4.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from ctranslate2==4.4.0) (75.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ctranslate2==4.4.0) (1.26.4)
# Requirement already satisfied: pyyaml<7,>=5.3 in /usr/local/lib/python3.10/dist-packages (from ctranslate2==4.4.0) (6.0.2)
# Using device: cuda:0
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# nvidia-cuda-toolkit is already the newest version (11.5.1-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 53 not upgraded.

# %%
#@markdown # **Model selection** 🧠

#@markdown There are several models to choose from, with varying performance and speed. large-v2 is recommended for most cases:

#@markdown |  Size  | Parameters | English-only model | Multilingual model | Required VRAM | Relative speed |
#@markdown |:------:|:----------:|:------------------:|:------------------:|:-------------:|:--------------:|
#@markdown |  tiny  |    39 M    |     `tiny.en`      |       `tiny`       |     ~0.8 GB     |      ~32x      |
#@markdown |  base  |    74 M    |     `base.en`      |       `base`       |     ~1.0 GB     |      ~16x      |
#@markdown | small  |   244 M    |     `small.en`     |      `small`       |     ~1.4 GB     |      ~6x       |
#@markdown | medium |   769 M    |    `medium.en`     |      `medium`      |     ~2.7 GB     |      ~2x       |
#@markdown | large-v1  |   1550 M   |        N/A         |      `large-v1`       |    ~4.3 GB     |       1x       |
#@markdown | large-v2  |   1550 M   |        N/A         |      `large-v2`       |    ~4.3 GB     |       1x       |

#@markdown ---
model_size = 'large-v2' #@param ['tiny', 'tiny.en', 'base', 'base.en', 'small', 'small.en', 'medium', 'medium.en', 'large-v1', 'large-v2', 'distil-large-v3']
device_type = "cuda" #@param {type:"string"} ['cuda', 'cpu']
compute_type = "float16" #@param {type:"string"} ['float16', 'int8_float16', 'int8']
#@markdown ---
#@markdown **Run this cell again if you change the model.**

model = WhisperModel(model_size, device=device_type, compute_type=compute_type)

# %%
#@markdown # **Video selection** 📺

#@markdown Enter the URL of the Youtube video **OR** Google drive video path of the video you want to translate/transcribe, and run the cell. Make sure the correct Type is chosen! This may take awhile depending on video file size.

Type = "Google Drive" #@param ['Youtube video or playlist', 'Google Drive', 'Direct download']
#@markdown ---
#@markdown #### **Youtube video or playlist**
URL = "" #@param {type:"string"}
# store_audio = True #@param {type:"boolean"}
#@markdown ---
#@markdown #### **Google Drive video, audio (mp4, wav), or folder containing video and/or audio files**
video_path = "Colab Notebooks/Faster Whisper/Meeting morning.mp3" #@param {type:"string"}
#@markdown ---
#@markdown #### **Direct Download**
ddl_url = "https://www.example.com/video.mkv" #@param {type:"string"}
#@markdown ---
#@markdown **Run this cell again if you change the video.**

video_path_local_list = []

if Type == "Youtube video or playlist":

    ydl_opts = {
        'format': 'm4a/bestaudio/best',
        'outtmpl': '%(id)s.%(ext)s',
        # ℹ️ See help(yt_dlp.postprocessor) for a list of available Postprocessors and their arguments
        'postprocessors': [{  # Extract audio using ffmpeg
            'key': 'FFmpegExtractAudio',
            'preferredcodec': 'wav',
        }]
    }

    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        error_code = ydl.download([URL])
        list_video_info = [ydl.extract_info(URL, download=False)]

    for video_info in list_video_info:
        video_path_local_list.append(Path(f"{video_info['id']}.wav"))

elif Type == "Google Drive":
    # video_path_drive = drive_mount_path / Path(video_path.lstrip("/"))
    video_path = drive_mount_path / Path(video_path.lstrip("/"))
    if video_path.is_dir():
        for video_path_drive in video_path.glob("**/*"):
            if video_path_drive.is_file():
                display(Markdown(f"**{str(video_path_drive)} selected for processing.**"))
            elif video_path_drive.is_dir():
                display(Markdown(f"**Subfolders not supported.**"))
            else:
                display(Markdown(f"**{str(video_path_drive)} does not exist, skipping.**"))
            video_path_local = Path(".").resolve() / (video_path_drive.name)
            shutil.copy(video_path_drive, video_path_local)
            video_path_local_list.append(video_path_local)
    elif video_path.is_file():
        video_path_local = Path(".").resolve() / (video_path.name)
        shutil.copy(video_path, video_path_local)
        video_path_local_list.append(video_path_local)
        print(f"{video_path_local} appended to list for processing")
        display(Markdown(f"**{str(video_path)} selected for processing.**"))
    else:
        display(Markdown(f"**{str(video_path)} does not exist.**"))

elif Type == "Direct download":
    print(f"⚠️ Please ensure this is a direct download link and is of a valid format")
    print(f"Attempting to download: {ddl_url}\n")
    # !wget {ddl_url} -O ddl_video.mp4
    # video_path_local_list.append("/content/ddl_video.mp4")

    response = requests.get(ddl_url)

    if response.status_code == 200:
        # Extract the filename from the URL
        filename = urlsplit(ddl_url).path.split("/")[-1]

        # Create the full path for the destination file in the current working directory
        destination_path = os.path.join(os.getcwd(), filename)

        # Save the file
        with open(destination_path, 'wb') as file:
            file.write(response.content)

        print(f"File downloaded successfully: {destination_path}")

        video_path_local = Path(".").resolve() / (filename)

        # print(f"Path local: {video_path_local}") # /content/video.mkv

        video_path_local_list.append(video_path_local)
    else:
        print(f"Failed to download file. Status code: {response.status_code}")

else:
    raise(TypeError("Please select supported input type."))

for video_path_local in video_path_local_list:
    valid_suffixes = [".mp4", ".mkv", ".mov", ".avi", ".wmv", ".flv", ".webm", ".3gp", ".mpeg"]

    print(f"Processing video file {video_path_local} with ffmpeg..")

    if video_path_local.suffix in valid_suffixes:
        input_suffix = video_path_local.suffix
        video_path_local = video_path_local.with_suffix(".wav")
        result = subprocess.run(["ffmpeg", "-i", str(video_path_local.with_suffix(input_suffix)), "-vn", "-acodec", "pcm_s16le", "-ar", "16000", "-ac", "1", str(video_path_local)])
# Out:
# /content/Meeting morning.mp3 appended to list for processing
# **/content/drive/My Drive/Colab Notebooks/Faster Whisper/Meeting morning.mp3 selected for processing.**
# Processing video file /content/Meeting morning.mp3 with ffmpeg..

# %%
def seconds_to_time_format(s):
    # Convert seconds to hours, minutes, seconds, and milliseconds
    hours = s // 3600
    s %= 3600
    minutes = s // 60
    s %= 60
    seconds = s // 1
    milliseconds = round((s % 1) * 1000)

    # Return the formatted string
    return f"{int(hours):02d}:{int(minutes):02d}:{int(seconds):02d},{int(milliseconds):03d}"

#@markdown # **Run the model** 🚀

#@markdown Run this cell to execute the transcription/translation of the video. This can take a while and very based on the length of the video and the number of parameters of the model selected above.

#@markdown ## **Parameters** ⚙️

#@markdown ### **Behavior control**
#@markdown #### Language
language = "en" #@param ["auto", "en", "zh", "ja", "fr", "de"] {allow-input: true}
#@markdown #### initial prompt (change to transcribe if you prefer transcribing only)
initial_prompt = "Transcribe this using glossary: Marcel, Dean, Su-anne, Ian, Steve, Sherman, Keith, Brian, Richelle, Lindsay, Lara, Kaylee,ORMS, VAT, UAT, DRP, API, ADE, Capterra, NDI, ERP, Associated Computer Solutions, Botswana Building Society, Adceng, Ceva Logistics, Geka, Jabula Plant Equipment, Avon Justine, Imperial Truck Rental, Premier Logistics Solutions, Goskor, FAW, NovoResults, Technotrain, Value Logistics, MAN Energy Solutions, Palian, Powertrain, SwaziBank, Tarsus, Hambanathi, BBS, SwaziBank, MAN-ES, Withholding tax, Postnet, Michelle, Richelle, FD, Sikie, Universe DR, Putco, Antalis, Kalideck, BEE, Marcel Kitay, Sherman Wilson, Su-anne Mitchell, Keith Pillay, Dean Wookey, Brian Mallory, ACS-Embrace, Netbasic, Embrace Desktop Bridge, Technotrain, Metaduct, MobiWork, Powertrain, Zest Weg, Plasson, Smith Power, ORMS Direct, Econofoods, Sturrock & Robson Industries, Brewtech, Lasercraft, Pecsser, Oilkol, Tarsus Shared Services, CNG Holdings, Antalis, Acumatica, Putco Limited, Astral, Vametco, Baytrac, Forbatt, Renttech, Paragon Van and Truck Hire, Habanathi Vehicle Hire, Equator Belt Group, CEG, CCS" #@param {type:"string"}
#@markdown ---
#@markdown #### Word-level timestamps
word_level_timestamps = False #@param {type:"boolean"}
#@markdown ---
#@markdown #### VAD filter
vad_filter = True #@param {type:"boolean"}
vad_filter_min_silence_duration_ms = 50 #@param {type:"integer"}
#@markdown ---
#@markdown #### Output (Default is srt, txt if `text_only` be checked )
text_only = True #@param {type:"boolean"}


segments, info = model.transcribe(str(video_path_local), beam_size=5,
                                  language=None if language == "auto" else language,
                                  initial_prompt=initial_prompt,
                                  word_timestamps=word_level_timestamps,
                                  vad_filter=vad_filter,
                                  vad_parameters=dict(min_silence_duration_ms=vad_filter_min_silence_duration_ms))

display(Markdown(f"Detected language '{info.language}' with probability {info.language_probability}"))

ext_name = '.txt' if text_only else ".srt"
output_file_name = video_path_local.stem + ext_name
sentence_idx = 1
with open(output_file_name, 'w') as f:
  for segment in segments:
    if word_level_timestamps:
      for word in segment.words:
        ts_start = seconds_to_time_format(word.start)
        ts_end = seconds_to_time_format(word.end)
        print(f"[{ts_start} --> {ts_end}] {word.word}")
        if not text_only:
          f.write(f"{sentence_idx}\n")
          f.write(f"{ts_start} --> {ts_end}\n")
          f.write(f"{word.word}\n\n")
        else:
          f.write(f"{word.word}")
        f.write("\n")
        sentence_idx = sentence_idx + 1
    else:
      ts_start = seconds_to_time_format(segment.start)
      ts_end = seconds_to_time_format(segment.end)
      print(f"[{ts_start} --> {ts_end}] {segment.text}")
      if not text_only:
        f.write(f"{sentence_idx}\n")
        f.write(f"{ts_start} --> {ts_end}\n")
        f.write(f"{segment.text.strip()}\n\n")
      else:
        f.write(f"{segment.text.strip()}\n")
      sentence_idx = sentence_idx + 1

try:
  files.download(output_file_name)
  shutil.copy(video_path_local.parent / output_file_name,
            drive_whisper_path / output_file_name
  )
  display(Markdown(f"**Output file created: {drive_whisper_path / output_file_name}**"))
except:
  display(Markdown(f"**Output file created: {video_path_local.parent / output_file_name}**"))
# Out:
# Detected language 'en' with probability 1
# [00:00:00,320 --> 00:00:13,630]  Again, I know there's no agency right now, so I'm going to put in the egg on my own.
# [00:00:13,630 --> 00:00:17,710]  It's so hot today.
# [00:00:17,710 --> 00:00:22,400]  What a day to choose.
# [00:00:22,400 --> 00:00:31,680]  I mean, yesterday by about two o'clock upstairs, because we've got big 35,000 BTU out there,
# [00:00:31,760 --> 00:00:40,830]  and it was 25, 26 already, and then I thought, no, I'm going to swim.
# [00:00:40,830 --> 00:00:42,990]  And the pool was 29.2.
# [00:00:42,990 --> 00:00:45,950]  Oh, no.
# [00:00:45,950 --> 00:00:48,990]  There's so much big repression.
# [00:00:48,990 --> 00:00:50,750]  Don't you like cold pools?
# [00:00:50,750 --> 00:00:52,430]  No, me neither.
# [00:10:25,680 --> 00:10:50,220]  Is there anything else on the financials?
# [00:11:20,880 --> 00:11:22,480]  Is there anything else on the financials?
# [00:11:24,140 --> 00:11:25,820]  Comments, observations, queries?
# [00:11:28,910 --> 00:11:31,070]  And then here's stuff we chose here.
# [00:11:31,070 --> 00:11:33,460]  Looking it up, they're back paid.
# [00:11:34,320 --> 00:11:35,600]  Sorry, we're on the data's review.
# [00:11:35,600 --> 00:11:49,060]  This is what I said earlier on.
# [00:11:49,060 --> 00:11:50,500]  We've just got 30 days.
# [00:11:59,680 --> 00:12:01,200]  Sorry, what's that you were saying?
# [00:12:01,200 --> 00:12:04,880]  No, I was ahead of you, so no problem.
# [00:12:04,880 --> 00:12:07,280]  No, no, I just said we're doing the data's now, so...
# [00:12:07,280 --> 00:12:09,680]  As far as your slot stands, as far as your slot stands,
# [00:12:09,680 --> 00:12:12,800]  we're doing some normal stuff.
# [00:12:22,270 --> 00:12:23,070]  You're chasing that.
# [00:12:24,800 --> 00:12:28,800]  Well, the last communication was that they would add all of the...
# [00:12:29,840 --> 00:12:31,120]  What do you call those certificates?
# [00:12:31,680 --> 00:12:34,240]  And that we were supposed to be collecting it.
# [00:12:34,240 --> 00:12:39,360]  So I'll follow up with Michelle about withholding tax certificate.
# [00:12:40,670 --> 00:12:45,710]  Because the last communication I got was that PostNet was instructed by your office,
# [00:12:45,710 --> 00:12:47,710]  our office, to collect the two certificates.
# [00:12:48,860 --> 00:12:51,740]  But DHL was on the way to collect on behalf of PostNet.
# [00:12:51,740 --> 00:12:53,020]  That is the last that I've got.
# [00:12:56,860 --> 00:13:02,640]  I'm assuming that I'll follow up with Michelle and check if she's received them
# [00:13:02,640 --> 00:13:04,880]  or what's happening with those withholding tax certificates.
# [00:13:04,880 --> 00:13:06,560]  Because that's what the amounts are.
# [00:13:07,250 --> 00:13:08,690]  It's just the withholding tax amounts.
# [00:13:16,060 --> 00:13:19,020]  So, just to go back to Manny, yes, we had meetings.
# [00:13:19,020 --> 00:13:22,220]  They've been chasing up the outstanding amounts.
# [00:13:24,140 --> 00:13:29,120]  The long, the old stuff, I've asked them to clear.
# [00:13:29,120 --> 00:13:31,920]  They've agreed to it, but they haven't yet got to it.
# [00:13:31,920 --> 00:13:37,310]  At the moment, Ruth will carry on following that up.
# [00:13:38,780 --> 00:13:43,020]  They did make a payment, and they're more or less clean.
# [00:13:47,170 --> 00:13:50,370]  So it is a bit confusing because of the two six amounts.
# [00:13:51,500 --> 00:13:55,420]  120 days, which is mostly covered by unallocated payment.
# [00:13:57,340 --> 00:13:59,420]  It's overcovered by the unallocated payment.
# [00:13:59,420 --> 00:14:02,940]  There's an excess of $25,000 everybody puts on it.
# [00:14:03,740 --> 00:14:07,410]  They're more focused at the moment on getting sign-off
# [00:14:07,410 --> 00:14:09,890]  from the old invoices and getting invoices back.
# [00:14:10,990 --> 00:14:12,990]  Are these still from when Michelle was here?
# [00:14:12,990 --> 00:14:13,710]  Yeah.
# [00:19:15,940 --> 00:19:16,740]  No, we did that for you.
# [00:19:16,740 --> 00:19:17,460]  That's all done.
# [00:19:17,460 --> 00:19:19,780]  So we raised POs,
# [00:19:19,780 --> 00:19:22,850]  and then when it came to getting payment
# [00:19:22,850 --> 00:19:24,450]  for some of the stuff now,
# [00:19:24,450 --> 00:19:25,490]  because he wasn't there,
# [00:19:25,490 --> 00:19:27,090]  then we're getting queries,
# [00:19:27,090 --> 00:19:28,560]  and then we addressed it.
# [00:19:29,680 --> 00:19:32,080]  So the, sorry, the RTT stuff,
# [00:19:33,220 --> 00:19:35,620]  the first lot of RTT stuff we did get paid.
# [00:19:36,260 --> 00:19:39,140]  I think there's a second lot that still has got to be sorted out.
# [00:19:39,220 --> 00:19:42,100]  The Australia stuff has been a bit of a delay.
# [00:19:42,100 --> 00:19:44,340]  So the second step, we're waiting for POs,
# [00:19:44,340 --> 00:19:45,620]  but we've done the work or not?
# [00:19:45,620 --> 00:19:47,460]  We've just, we're about to raise an invoice.
# [00:19:47,460 --> 00:19:49,060]  Ruth is going to raise an invoice.
# [00:19:49,060 --> 00:19:51,970]  So the first lot we got the PO for it.
# [00:19:52,880 --> 00:19:55,200]  The Australia stuff we got POs for,
# [00:19:55,200 --> 00:19:57,120]  but the payment hadn't come through yet
# [00:19:57,120 --> 00:19:58,000]  because we're waiting.
# [00:19:58,690 --> 00:20:02,350]  The sign-off because of cloud issues.
# [00:20:02,350 --> 00:20:03,950]  So I've not got sure of the current status
# [00:20:03,950 --> 00:20:05,150]  of what's happening.
# [00:20:05,150 --> 00:20:07,630]  But it's, I think it's all more,
# [00:20:07,630 --> 00:20:09,710]  pretty much under control for a period of time.
# [00:20:12,850 --> 00:20:15,170]  Getting clearly clear in this country.
# [00:20:15,170 --> 00:20:24,880]  I think we're better than the million balance.
# [00:20:24,880 --> 00:20:25,680]  Sorry?
# [00:20:25,680 --> 00:20:27,600]  I think we're probably better than the million balance.
# [00:20:27,600 --> 00:20:28,240]  No, that's what I'm saying.
# [00:20:28,240 --> 00:20:30,320]  We received a payment of $670.
# [00:20:30,320 --> 00:20:32,960]  So this is as at the 31st of October.
# [00:20:32,960 --> 00:20:34,640]  The payment came in over the weekend.
# [00:20:34,640 --> 00:20:39,900]  So I'm guessing they paid most of that 60-day payments,
# [00:20:39,900 --> 00:20:40,540]  sort of thing,
# [00:20:40,540 --> 00:20:43,310]  which was those POs that we raised.
# [00:20:43,310 --> 00:20:47,010]  And it's still showing a million.
# [00:20:47,010 --> 00:20:52,750]  It's still showing a million, yeah.
# [00:20:54,350 --> 00:20:56,030]  I looked at the bank statement.
# [00:20:56,030 --> 00:20:56,830]  I looked at the cash.
# [00:20:57,950 --> 00:20:59,820]  She might not have processed that yet.
# [00:21:22,510 --> 00:21:23,630]  She's had feedback there.
# [00:21:23,630 --> 00:21:24,510]  They will be paying.
# [00:21:25,580 --> 00:21:29,390]  All of our contacts there have left the building.
# [00:21:29,390 --> 00:21:33,840]  So she's now established contact with Philippoo.
# [00:25:44,370 --> 00:25:50,370]  The person whose decision it is is a guy called Stephanos.
# [00:25:50,370 --> 00:25:57,650]  And he prefers having an integrated system as opposed to two separate systems.
# [00:25:57,650 --> 00:25:59,090]  So that plays in our favor.
# [00:26:00,450 --> 00:26:04,930]  And they are just waiting for their head office in Dubai
# [00:26:04,930 --> 00:26:09,860]  to choose what the financial reporting system will be for Oracle.
# [00:26:09,860 --> 00:26:11,860]  And then once that decision is made,
# [00:26:11,860 --> 00:26:15,220]  then we'll get the guy ahead.
# [00:26:15,940 --> 00:26:19,620]  So that, whilst it's moved forward, we're still waiting.
# [00:26:20,340 --> 00:26:22,500]  Then the next up is FAW.
# [00:26:24,580 --> 00:26:30,270]  This, I've managed to speak to one of the guys last week.
# [00:26:30,990 --> 00:26:33,870]  We're basically at risk of losing it to SAP
# [00:26:35,870 --> 00:26:40,190]  because SAP is in conversations with them at the moment.
# [00:26:40,750 --> 00:26:48,720]  But I've not had Daphne, the CFO, take my call in easy six weeks.
# [00:26:49,600 --> 00:26:51,120]  So that's concerning.
# [00:26:51,120 --> 00:26:53,600]  And is it business one they're looking at or full SAP?
# [00:26:54,670 --> 00:26:55,710]  It'll be full SAP.
# [00:26:56,480 --> 00:26:57,760]  You see, they're on business one at the moment.
# [00:26:57,760 --> 00:26:58,480]  No, no.
# [00:26:58,480 --> 00:27:00,000]  They're on it and they have an extension.
# [00:27:00,000 --> 00:27:01,360]  It's not doing everything.
# [00:27:01,360 --> 00:27:02,640]  No, no, no, it's not.
# [00:27:02,640 --> 00:27:04,160]  Or maybe they're going to expand it.
# [00:27:04,160 --> 00:27:05,100]  Yeah.
# [00:27:05,100 --> 00:27:08,220]  Well, it seems that that's the conversation that is being had
# [00:27:09,020 --> 00:27:11,260]  for SAP to take over everything.
# [00:27:11,340 --> 00:27:15,020]  But SAP doesn't have a WMS system like what we do.
# [00:27:15,020 --> 00:27:18,780]  And the biggest push right now is on the WMS side.
# [00:27:19,570 --> 00:27:23,730]  So I'm a bit concerned about that.
# [00:27:23,730 --> 00:27:25,810]  But I will keep pushing.
# [00:27:25,810 --> 00:27:31,630]  And I'll also send an email to the effect that SAP does not have a WMS.
# [00:27:33,860 --> 00:27:39,220]  And of course, SAP didn't have a manned bus and truck case study on their website either,
# [00:27:40,100 --> 00:27:42,740]  which is what brought them to us.
# [00:27:43,540 --> 00:27:47,700]  The 60 users that you've got listed on the point of sale, is that the dealer users?
# [00:27:48,640 --> 00:27:49,040]  Yes.
# [00:27:49,040 --> 00:27:50,480]  I don't have a dealer user column.
# [00:27:50,480 --> 00:27:51,600]  I can add one in if you want.
# [00:27:51,600 --> 00:27:52,400]  No, no, no, no, no, no.
# [00:27:52,400 --> 00:27:57,620]  It's just clarity.
# [00:28:00,100 --> 00:28:04,900]  And then the next up is OneLogix.
# [00:28:06,290 --> 00:28:12,130]  So OneLogix is a huge, huge deal.
# [00:28:12,850 --> 00:28:19,460]  They basically, the guy that they had to manage the whole ERP project,
# [00:28:20,020 --> 00:28:26,000]  has now been given the MD role at a branch called Mulas.
# [00:34:27,860 --> 00:34:32,340]  So on, I think it's the 26th of this month,
# [00:34:32,340 --> 00:34:33,220]  we've got Warren,
# [00:34:33,220 --> 00:34:36,420]  the new CFO who's going to come in here
# [00:34:36,420 --> 00:34:38,260]  and see a demo of Embrace.
# [00:34:40,240 --> 00:34:42,480]  So he literally just started,
# [00:34:43,600 --> 00:34:48,200]  I think, in week one of last month.
# [00:34:48,200 --> 00:34:50,600]  So he's still learning the names
# [00:34:50,600 --> 00:34:51,640]  of the people around him.
# [00:34:53,600 --> 00:34:57,760]  But they're looking to go ahead
# [00:34:57,760 --> 00:35:00,520]  as soon as he's up and running.
# [00:35:01,510 --> 00:35:03,830]  Then next is Haval
# [00:35:04,470 --> 00:35:06,310]  for the WMS implementation.
# [00:35:08,480 --> 00:35:10,240]  So just this morning,
# [00:35:11,120 --> 00:35:15,300]  we resubmitted some pricing for them.
# [00:35:15,300 --> 00:35:18,480]  They don't want to rent
# [00:35:18,480 --> 00:35:20,000]  the hardware from us anymore.
# [00:35:21,520 --> 00:35:24,640]  And they told us that we were twice
# [00:35:24,640 --> 00:35:27,360]  the price of the other vendors
# [00:35:28,240 --> 00:35:30,320]  that we are up against.
# [00:35:30,880 --> 00:35:36,880]  So for the implementation side of things.
# [00:35:37,440 --> 00:35:39,200]  And the hardware,
# [00:35:39,200 --> 00:35:40,480]  we were just out of the ballpark.
# [00:35:40,480 --> 00:35:42,640]  So they said, take the hardware out,
# [00:35:42,640 --> 00:35:44,720]  we'll get the hardware ourselves.
# [00:35:44,720 --> 00:35:46,480]  Because they've already got some QDAs
# [00:35:46,480 --> 00:35:48,240]  and what have you in their warehouse.
# [00:35:48,240 --> 00:35:50,880]  So they've got a supplier of sorts.
# [00:35:50,880 --> 00:35:57,640]  But then Ian and I took the opportunity
# [00:35:57,720 --> 00:36:01,160]  to just revise our pricing there
# [00:36:01,160 --> 00:36:04,680]  and resubmit a slightly lower price,
# [00:36:05,640 --> 00:36:08,120]  which I did just before coming into this meeting.
# [00:36:08,120 --> 00:36:11,890]  Which I think is an absolute blessing
# [00:36:11,890 --> 00:36:15,170]  because we were having the conversation
# [00:36:15,170 --> 00:36:16,450]  just a few weeks ago.
# [00:36:17,330 --> 00:36:20,850]  Out of all the times that we've lost the business,
# [00:36:20,850 --> 00:36:23,970]  not once has anyone ever come back to us
# [00:36:23,970 --> 00:36:25,170]  and said, you know what,
# [00:36:25,170 --> 00:36:27,650]  you're too expensive on this.
# [00:36:27,650 --> 00:36:30,530]  If you can just adjust this or do that,
# [00:36:31,170 --> 00:36:33,170]  we can allocate you the business.
# [00:36:33,170 --> 00:36:36,050]  Never once in the five years I've worked here.
# [00:36:36,050 --> 00:36:40,210]  So now we've taken the opportunity
# [00:36:40,210 --> 00:36:45,410]  to put in a slightly revised price there.
# [00:36:45,970 --> 00:36:51,030]  And fingers crossed, we'll see what happens.
# [00:36:51,030 --> 00:36:56,480]  But the decision to choose the WMS supplier
# [00:36:56,480 --> 00:36:58,000]  should take place this month.
# [00:36:58,720 --> 00:37:01,200]  You know, it should happen imminently.
# [00:37:02,710 --> 00:37:04,550]  Are you disconfident now with Hyrule?
# [00:37:08,390 --> 00:37:09,510]  No, I'm not.
# [00:37:12,390 --> 00:37:14,710]  The pause was due to them
# [00:37:15,510 --> 00:37:17,030]  wanting to enable the process,
# [00:37:18,470 --> 00:37:19,510]  which is fine.
# [00:37:19,510 --> 00:37:21,830]  But obviously I just want the process to happen faster.
# [00:37:22,870 --> 00:37:24,070]  You know, now that the new guys,
# [00:37:24,070 --> 00:37:27,940]  you started the beginning of, end of September?
# [00:37:28,900 --> 00:37:31,220]  Beginning of last month, October.
# [00:37:31,220 --> 00:37:32,180]  Yeah, so it was the end of September,
# [00:37:32,180 --> 00:37:33,540]  the 26th of September.
# [00:37:33,540 --> 00:37:36,100]  So we were hoping that if you'd hit the ground running
# [00:37:36,100 --> 00:37:37,380]  and we would pick up momentum.
# [00:37:37,380 --> 00:37:39,940]  But here's like, I'm new to the business,
# [00:37:39,940 --> 00:37:41,140]  I don't know the lay of the land,
# [00:37:41,140 --> 00:37:42,740]  I can't really evaluate.
# [00:37:43,460 --> 00:37:45,860]  So we were hoping to get something set
# [00:37:47,160 --> 00:37:48,200]  earlier in November.
# [00:37:50,720 --> 00:37:51,760]  We'll get the business.
# [00:37:52,480 --> 00:37:57,430]  It'll just come in a little later than a little sooner.
# [00:37:58,530 --> 00:38:00,850]  And then the next step is Econo Foods.
# [00:38:01,730 --> 00:38:07,190]  So Econo Foods is a nice sized deal.
# [00:38:07,750 --> 00:38:13,110]  It's 100 users, 42 WMS, and 108 point of sales.
# [00:38:13,990 --> 00:38:19,970]  So by far the largest deal that we've come across
# [00:38:20,610 --> 00:38:23,890]  since I've started here, with the exception of RentTech.
# [00:38:24,690 --> 00:38:30,260]  And so their CFO, Grant Hughes, reached out to me
# [00:38:30,900 --> 00:38:35,030]  and when we went down and demoed to them,
# [00:38:35,030 --> 00:38:37,910]  Grant was in the meeting,
# [00:38:37,910 --> 00:38:43,970]  but he had forgotten that it was us, you know,
# [00:38:45,680 --> 00:38:47,200]  us salespeople, you know,
# [00:38:47,200 --> 00:38:49,920]  we think that they'll remember our name the next day,
# [00:38:49,920 --> 00:38:50,560]  but they don't.
# [00:38:53,110 --> 00:38:54,870]  Didn't they have a problem with sales
# [00:38:54,870 --> 00:38:56,390]  and that's why this whole thing?
# [00:38:56,390 --> 00:38:57,830]  No, that was Jiguli.
# [00:38:57,830 --> 00:38:59,830]  So Econo Foods is one we probably saw
# [00:38:59,830 --> 00:39:01,430]  about two and a half years ago.
# [00:39:02,150 --> 00:39:03,110]  It was three years ago.
# [00:39:03,110 --> 00:39:03,990]  Three years ago.
# [00:39:03,990 --> 00:39:05,590]  No, so Jiguli is the one in Hardin.
# [00:39:05,590 --> 00:39:08,390]  These are the guys we flew down to Bloemfontein.
# [00:39:08,390 --> 00:39:12,040]  Yeah, why did it go quiet?
# [00:39:12,040 --> 00:39:13,560]  Because it was hot and then...
# [00:41:10,980 --> 00:41:11,780]  should we not be?
# [00:41:11,780 --> 00:41:13,460]  At least two and a half years.
# [00:41:13,460 --> 00:41:14,740]  Well, or two.
# [00:41:14,740 --> 00:41:16,900]  Or maybe six months because things do change.
# [00:41:17,860 --> 00:41:18,580]  You know what, Dean?
# [00:41:18,580 --> 00:41:21,540]  I was fully on board with that line of thinking
# [00:41:21,540 --> 00:41:24,740]  for the first five years of me working here.
# [00:41:26,880 --> 00:41:27,600]  Now I've learned.
# [00:41:28,320 --> 00:41:31,200]  It's not something that if they say,
# [00:41:31,200 --> 00:41:32,400]  oh, give me two years,
# [00:41:32,400 --> 00:41:36,070]  you find them in like basically 20 months
# [00:41:36,070 --> 00:41:37,590]  as opposed to 24 months.
# [00:41:37,590 --> 00:41:39,030]  Then they say, no, no, you know,
# [00:41:39,030 --> 00:41:40,550]  let's speak in a year's time.
# [00:41:40,550 --> 00:41:43,270]  It's never a case of, I mean,
# [00:41:43,270 --> 00:41:46,630]  this is the one and only where it's been
# [00:41:46,630 --> 00:41:49,510]  as close to three years as can be.
# [00:41:49,510 --> 00:41:54,660]  But don't worry, I do schedule them in my calendar.
# [00:41:56,580 --> 00:41:58,740]  So you used to do it, but you stopped doing it.
# [00:41:58,740 --> 00:42:01,780]  And all of those cloud leads are piling up,
# [00:42:01,780 --> 00:42:02,340]  I'm just saying.
# [00:42:05,120 --> 00:42:08,520]  Hmm, I'm just asking.
# [00:42:09,620 --> 00:42:10,660]  So you've stopped doing it.
# [00:42:11,590 --> 00:42:13,270]  You used to do it, but you stopped doing it.
# [00:42:13,270 --> 00:42:19,560]  I've stopped doing it prior to the whatever date it was.
# [00:42:19,560 --> 00:42:21,240]  If they say call me in six months,
# [00:42:21,240 --> 00:42:22,200]  I call them in six months.
# [00:42:22,200 --> 00:42:23,640]  I'm not going to find them in four months
# [00:42:24,440 --> 00:42:27,400]  to try and, you know, get them all excited.
# [00:42:27,400 --> 00:42:29,510]  That doesn't work.
# [00:42:29,510 --> 00:42:32,390]  It comes down to time, resources and money.
# [00:42:33,240 --> 00:42:36,360]  And yeah, very rarely do you get all three,
# [00:42:37,640 --> 00:42:38,280]  all together.
# [00:42:39,360 --> 00:42:39,600]  Okay.
# [00:42:40,240 --> 00:42:45,940]  But yeah, I still schedule them to follow up.
# [00:42:49,170 --> 00:42:56,600]  And then Humbanati, you know, Humbanati basically,
# [00:42:59,810 --> 00:43:01,570]  they've now changed their business model.
# [00:43:02,210 --> 00:43:07,620]  They are focusing more on short-term car rentals.
# [00:43:07,620 --> 00:43:09,940]  Now they're looking at, what's that thing called?
# [00:43:10,740 --> 00:43:15,810]  Rental car manager.
# [00:43:15,810 --> 00:43:16,290]  RCM.
# [00:43:16,290 --> 00:43:18,130]  RCM, yeah.
# [00:43:18,130 --> 00:43:19,730]  So we're going to integrate into that.
# [00:43:25,010 --> 00:43:27,250]  Well, when I spoke to Jake the first time,
# [00:43:27,250 --> 00:43:30,630]  the first time he called, he already made up his mind.
# [02:59:24,960 --> 02:59:25,680]  No, it's...
# [02:59:25,680 --> 02:59:27,120]  Oh, they've got a closed network.
# [02:59:27,120 --> 02:59:27,620]  Yeah.
# [02:59:28,560 --> 02:59:29,520]  I just assumed.
# [02:59:29,520 --> 02:59:30,400]  So I thought, okay,
# [02:59:30,400 --> 02:59:32,000]  how come we aren't getting problem C?
# [02:59:32,000 --> 02:59:33,440]  Because they are in the cloud.
# [02:59:33,440 --> 02:59:34,960]  But they've got a closed network.
# [02:59:35,870 --> 02:59:37,390]  So when we issue that on,
# [02:59:37,390 --> 02:59:38,750]  so printing, it affects everyone.
# [02:59:40,360 --> 02:59:43,320]  But Claude is because he's got it open.
# [02:59:43,320 --> 02:59:44,680]  He's checking the mail.
# [02:59:44,680 --> 02:59:46,600]  I don't think it affects anyone anymore.
# [02:59:46,600 --> 02:59:48,520]  Yeah, well, they haven't yet, hopefully.
# [02:59:48,520 --> 02:59:51,160]  Because we resolved that.
# [02:59:51,160 --> 02:59:52,920]  And on a Wednesday morning,
# [02:59:52,920 --> 02:59:53,720]  it says reboot.
# [02:59:55,000 --> 02:59:55,720]  Is that sorted out?
# [02:59:55,720 --> 02:59:57,080]  Just be careful when you reboot.
# [02:59:57,080 --> 02:59:59,400]  No, we're not rebooting.
# [03:00:00,040 --> 03:00:02,600]  You said something runs on the AWS server?
# [03:00:02,600 --> 03:00:05,160]  Yeah, it's trying to do something automatic
# [03:00:05,160 --> 03:00:06,040]  and we don't know what,
# [03:00:06,040 --> 03:00:07,160]  but it doesn't have permissions.
# [03:00:07,160 --> 03:00:07,880]  And it's...
# [03:00:07,880 --> 03:00:08,840]  So don't worry about that.
# [03:00:08,840 --> 03:00:10,360]  Okay, so that's sorted out.
# [03:00:10,360 --> 03:00:11,400]  Well, it's not sorted out.
# [03:00:11,400 --> 03:00:12,400]  What were they doing with it
# [03:00:12,400 --> 03:00:15,020]  when they got the whole box of printing?
# [03:00:18,560 --> 03:00:19,600]  Yeah, that was...
# [03:00:19,600 --> 03:00:20,320]  They sorted it out.
# [03:00:20,320 --> 03:00:21,120]  A reboot.
# [03:00:21,120 --> 03:00:22,160]  Just turn the paper over
# [03:00:22,160 --> 03:00:23,120]  and use the other side.
# [03:00:23,680 --> 03:00:25,280]  That was a long time ago.
# [03:00:25,280 --> 03:00:26,720]  It was re-submitting the jobs.
# [03:00:27,520 --> 03:00:28,560]  When you're doing an update.
# [03:00:28,560 --> 03:00:29,920]  The boxes of stuff.
# [03:00:29,920 --> 03:00:30,640]  For the wireless.
# [03:00:31,390 --> 03:00:32,910]  I think it was due with reboots.
# [03:00:34,840 --> 03:00:36,840]  It wasn't clearing out the jobs with it.
# [03:00:39,290 --> 03:00:41,450]  Yeah, I think it was due with reboots.
# [03:00:42,010 --> 03:00:47,820]  So definitely after hours, if possible,
# [03:00:47,820 --> 03:00:49,260]  if it doesn't come to a standstill.
# [03:00:53,260 --> 03:00:55,500]  But yeah, I'm slightly suspecting
# [03:00:55,500 --> 03:00:56,700]  it's Infinetix.
# [03:04:09,100 --> 03:04:10,380]  No, but I will speak to Jason
# [03:04:10,380 --> 03:04:11,500]  before the announcement.
# [03:04:11,500 --> 03:04:12,940]  I just didn't want to send the email
# [03:04:12,940 --> 03:04:14,840]  once I'd responded
# [03:04:14,840 --> 03:04:16,280]  because I wanted to get some feedback.
# [03:04:17,560 --> 03:04:18,060]  And Keith,
# [03:04:19,240 --> 03:04:20,280]  because I just remembered,
# [03:04:20,280 --> 03:04:21,880]  Claude said that he was going to
# [03:04:22,600 --> 03:04:26,280]  remove Stunlaw out of the equation,
# [03:04:26,280 --> 03:04:27,320]  which is the encryption.
# [03:04:27,560 --> 03:04:28,920]  Software that we use
# [03:04:28,920 --> 03:04:30,680]  and create their own...
# [03:04:31,480 --> 03:04:32,920]  The reason we put Stunlaw is
# [03:04:32,920 --> 03:04:34,520]  because then you can see there is...
# [03:04:35,240 --> 03:04:37,240]  Yeah, so I don't know
# [03:04:37,240 --> 03:04:38,760]  if he's actually going to do that.
# [03:04:38,760 --> 03:04:39,880]  He said to me he was...
# [03:04:39,880 --> 03:04:41,080]  No, I'll speak to him
# [03:04:41,080 --> 03:04:42,600]  because also what we said is
# [03:04:42,600 --> 03:04:43,640]  at WebCo,
# [03:04:43,640 --> 03:04:45,480]  we use the Windows SMTP.
# [03:04:45,480 --> 03:04:45,980]  That's right.
# [03:04:46,760 --> 03:04:47,880]  And there you can change
# [03:04:47,880 --> 03:04:50,600]  the limit of the timing
# [03:04:50,600 --> 03:04:51,100]  and whatever.
# [03:04:52,040 --> 03:04:54,040]  So that's what he wants to do.
# [03:04:54,040 --> 03:04:55,000]  And if he does that,
# [03:04:55,000 --> 03:04:57,080]  that might solve the problem.
# [03:04:58,190 --> 03:05:00,440]  Because we are piping
# [03:05:00,440 --> 03:05:01,880]  through various things
# [03:05:01,880 --> 03:05:03,320]  and Stunlaw is one of them
# [03:05:03,320 --> 03:05:06,040]  and it's not my favorite piece of software.
# [03:05:06,040 --> 03:05:06,540]  Yeah.
# [03:05:07,080 --> 03:05:08,760]  But we got that done in the TLS
# [03:05:08,760 --> 03:05:10,840]  and SSL reaction course as well.
# [03:05:10,840 --> 03:05:11,340]  Yeah.
# [03:05:13,260 --> 03:05:16,300]  So that's also part of the project.
# [03:05:16,300 --> 03:05:16,800]  Yeah.
# [03:05:26,380 --> 03:05:27,580]  Come to break in two seconds.
# [03:05:28,860 --> 03:05:29,740]  I think so, yes.
# [03:05:30,620 --> 03:05:32,300]  I set my thing to 11 o'clock
# [03:05:32,300 --> 03:05:35,740]  and then we have 10 past 12.
# [03:05:36,540 --> 03:05:37,740]  So it's lunch.
# [03:05:38,940 --> 03:05:40,940]  They have great food.
# [03:05:42,060 --> 03:05:43,580]  Shall we break for a few minutes?
# [03:05:45,690 --> 03:05:47,130]  They can't be breaking.
# [03:05:47,130 --> 03:05:50,410]  I'll ask them to send a message out.
# **Output file created: /content/drive/My Drive/Colab Notebooks/Faster Whisper/Meeting morning.txt**
